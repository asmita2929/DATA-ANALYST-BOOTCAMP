# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/asmitasingh/Downloads/aug_train.csv")

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
pd.read_csv("/Users/asmitasingh/Downloads/aug_train.csv",index_col='enrollee_id')
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 2785          city_21                   0.624   Male   No relevent experience
# 16221        city_102                   0.804   Male  Has relevent experience
# 15749        city_136                   0.897    NaN  Has relevent experience
# 23759         city_21                   0.624    NaN   No relevent experience
# 24692        city_142                   0.727   Male  Has relevent experience
#
# ...

# %%
pd.read_csv("/Users/asmitasingh/Downloads/aug_train.csv",usecols=['enrollee_id','gender','relevent_experience','education_level','company_size'])
# Out:
#        enrollee_id gender      relevent_experience education_level  \
# 0             8949   Male  Has relevent experience        Graduate
# 1            29725   Male   No relevent experience        Graduate
# 2            11561    NaN   No relevent experience        Graduate
# 3            33241    NaN   No relevent experience        Graduate
# 4              666   Male  Has relevent experience         Masters
# ...            ...    ...                      ...             ...
# 10231         2785   Male   No relevent experience         Masters
# 10232        16221   Male  Has relevent experience         Masters
# 10233        15749    NaN  Has relevent experience         Masters
# 10234        23759    NaN   No relevent experience     High School
# 10235        24692   Male  Has relevent experience        Graduate
#
#       company_size
# 0              NaN
# 1            50-99
# 2              NaN
# 3              NaN
# 4            50-99
# ...            ...
# ...

# %%
pd.read_csv("/Users/asmitasingh/Downloads/aug_train.csv",nrows=100)
# Out:
#     enrollee_id      city  city_development_index gender  \
# 0          8949  city_103                   0.920   Male
# 1         29725   city_40                   0.776   Male
# 2         11561   city_21                   0.624    NaN
# 3         33241  city_115                   0.789    NaN
# 4           666  city_162                   0.767   Male
# ..          ...       ...                     ...    ...
# 95        12081   city_65                   0.802   Male
# 96         7364  city_160                   0.920    NaN
# 97        11184   city_74                   0.579    NaN
# 98         7016   city_65                   0.802   Male
# 99         8695   city_11                   0.550   Male
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# ...

# %%
# !pip install mysql.connector
import mysql.connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 24.9 MB/s eta 0:00:00 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp312-cp312-macosx_11_0_arm64.whl size=247957 sha256=457dd755911c4647b8423fdf1822b1732a79de550b1b6b7379ee7259cf895400
#   Stored in directory: /Users/asmitasingh/Library/Caches/pip/wheels/03/17/fa/d7604c72dd3dd6d3eb3d249abf36cc532c9a9b4354b8f1bc4f
# Successfully built mysql.connector
# ...

# %%
import mysql.connector

# %%
conn=mysql.connector.connect(host="localhost",user="root",password="",db="temp_db")

# %%
import pandas as pd

# %%
invoices=pd.read_sql_query('select * from invoices',conn)
# Out:
# /var/folders/5v/g0nqjmns1xs7xr77qnjdjgz00000gn/T/ipykernel_49153/725973401.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   invoices=pd.read_sql_query('select * from invoices',conn)

# %%
invoices.head()
# Out:
#            Order Id                 Date           Meal Id        Company Id  \
# 0  839FKFW2LLX4LMBB           27-05-2016  INBUX904GIHI8YBD  LJKS5NK6788CYMUU
# 1  97OX39BGVMHODLJM           27-09-2018  J0MMOOPP709DIDIE  LJKS5NK6788CYMUU
# 2  041ORQM5OIHTIU6L           24-08-2014  E4UJLQNCI16UX5CS  LJKS5NK6788CYMUU
# 3  YT796QI18WNGZ7ZJ  2014-12-04 00:00:00  C9SDFHF7553BE247  LJKS5NK6788CYMUU
# 4  6YLROQT27B6HRF4E           28-07-2015  48EQXS6IHYNZDDZ5  LJKS5NK6788CYMUU
#
#                 Date of Meal                       Participants  Meal Price  \
# 0  2016-05-31 07:00:00+02:00                   ['David Bishop']         469
# 1  2018-10-01 20:00:00+02:00                   ['David Bishop']          22
# 2  2014-08-23 14:00:00+02:00                 ['Karen Stansell']         314
# 3  2014-04-07 21:00:00+02:00                   ['Addie Patino']         438
# 4  2015-07-27 14:00:00+02:00  ['Addie Patino' 'Susan Guerrero']         690
#
#   Type of Meal
# 0    Breakfast
# ...

# %%
orderleads=pd.read_sql_query('select * from orderleads',conn)
# Out:
# /var/folders/5v/g0nqjmns1xs7xr77qnjdjgz00000gn/T/ipykernel_49153/3144199801.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   orderleads=pd.read_sql_query('select * from orderleads',conn)

# %%
orderleads.head()
# Out:
#            Order Id        Company Id            Company Name        Date  \
# 0  80EYLOKP9E762WKG  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  18-02-2017
# 1  TLEXR1HZWTUTBHPB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  30-07-2015
# 2  839FKFW2LLX4LMBB  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  27-05-2016
# 3  97OX39BGVMHODLJM  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  27-09-2018
# 4  5T4LGH4XGBWOD49Z  LJKS5NK6788CYMUU  Chimera-Chasing Casbah  14-01-2016
#
#    Order Value  Converted
# 0         4875          1
# 1         8425          0
# 2         4837          0
# 3          343          0
# 4          983          0

# %%
salesteam=pd.read_sql_query('select * from salesteam',conn)
# Out:
# /var/folders/5v/g0nqjmns1xs7xr77qnjdjgz00000gn/T/ipykernel_49153/88303637.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   salesteam=pd.read_sql_query('select * from salesteam',conn)

# %%
salesteam.head()
# Out:
#            Sales Rep      Sales Rep Id                    Company Name  \
# 0  Jessie Mcallister  97UNNAT790E0WM4N          Chimera-Chasing Casbah
# 1  Jessie Mcallister  97UNNAT790E0WM4N                Tangential Sheds
# 2  Jessie Mcallister  97UNNAT790E0WM4N                   Two-Mile Grab
# 3  Jessie Mcallister  97UNNAT790E0WM4N  Three-Men-And-A-Helper Congo'S
# 4  Jessie Mcallister  97UNNAT790E0WM4N        Biophysical Battleground
#
#          Company Id
# 0  LJKS5NK6788CYMUU
# 1  36MFTZOYMTAJP1RK
# 2  H3JRC7XX7WJAD4ZO
# 3  HB25MDZR0MGCQUGX
# 4  7RVA8TIVBLBXMNO4

# %%
with pd.ExcelWriter('supermarket.xlsx')as writer:
    invoices.to_excel(writer,sheet_name ="invoices")
    orderleads.to_excel(writer,sheet_name ="orderleads")
    salesteam.to_excel(writer,sheet_name="salesteam")

# %%
### code here
### Rapid API 
import requests

url = "https://wft-geo-db.p.rapidapi.com/v1/geo/adminDivisions"

headers = {
    "X-RapidAPI-Key": "b0f75c828fmsh2b0480a62ab8d23p18178ajsn3267e033ae6a",
    "X-RapidAPI-Host": "wft-geo-db.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

data = response.json()['data']
links = response.json()['links']
metadata = response.json()['metadata']
print(response.text)
# Out:
# {"links":[{"rel":"first","href":"/v1/geo/adminDivisions?offset=0&limit=5"},{"rel":"next","href":"/v1/geo/adminDivisions?offset=5&limit=5"},{"rel":"last","href":"/v1/geo/adminDivisions?offset=74810&limit=5"}],"data":[{"id":3515514,"wikiDataId":"Q4117373","name":"Al Mamzar","country":"United Arab Emirates","countryCode":"AE","region":"Emirate of Dubai","regionCode":"DU","regionWdId":"Q613","latitude":25.309469444,"longitude":55.342811111,"population":0},{"id":3671889,"wikiDataId":"Q1262899","name":"Dubai Internet City","country":"United Arab Emirates","countryCode":"AE","region":"Emirate of Dubai","regionCode":"DU","regionWdId":"Q613","latitude":25.095,"longitude":55.16,"population":24000},{"id":3386644,"wikiDataId":"Q3694483","name":"Ab Band District","country":"Afghanistan","countryCode":"AF","region":"Ghazni Province","regionCode":"GHA","regionWdId":"Q180415","latitude":32.983,"longitude":67.967,"population":0},{"id":3339608,"wikiDataId":"Q2572213","name":"Ab Kamari","country":"Afgh
# ...

# %%
data = response.json()['data']
data
# Out:
# [{'id': 3515514,
#   'wikiDataId': 'Q4117373',
#   'name': 'Al Mamzar',
#   'country': 'United Arab Emirates',
#   'countryCode': 'AE',
#   'region': 'Emirate of Dubai',
#   'regionCode': 'DU',
#   'regionWdId': 'Q613',
#   'latitude': 25.309469444,
#   'longitude': 55.342811111,
#   'population': 0},
#  {'id': 3671889,
#   'wikiDataId': 'Q1262899',
#   'name': 'Dubai Internet City',
#   'country': 'United Arab Emirates',
#   'countryCode': 'AE',
#   'region': 'Emirate of Dubai',
#   'regionCode': 'DU',
#   'regionWdId': 'Q613',
#   'latitude': 25.095,
#   'longitude': 55.16,
#   'population': 24000},
#  {'id': 3386644,
#   'wikiDataId': 'Q3694483',
#   'name': 'Ab Band District',
#   'country': 'Afghanistan',
#   'countryCode': 'AF',
#   'region': 'Ghazni Province',
#   'regionCode': 'GHA',
#   'regionWdId': 'Q180415',
#   'latitude': 32.983,
#   'longitude': 67.967,
#   'population': 0},
#  {'id': 3339608,
#   'wikiDataId': 'Q2572213',
#   'name': 'Ab Kamari',
# ...
